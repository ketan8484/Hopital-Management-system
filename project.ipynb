# %%
import tkinter as tk
from tkinter import ttk
from tkinter import messagebox
import random
import datetime
import mysql.connector


class Hospital:
    def __init__(self,root):
        self.root=root
        self.root.title("Hospital Management System")
        self.root.geometry("1520x800+0+0")
        
        #=================================variables for DB=================
        
        self.Nameofmedicine=tk.StringVar()
        self.ReferenceNo=tk.DoubleVar()
        self.Dose=tk.StringVar()
        self.MedicineQuntity=tk.StringVar()
        self.Lot=tk.StringVar()
        self.Issuedate=tk.StringVar()
        self.Expirydate=tk.StringVar()
        self.Dailydose=tk.StringVar()
        self.sideEffect=tk.StringVar()
        self.FurtherInformation=tk.StringVar()
        self.Storageadvice=tk.StringVar()
        self.Drivingusingmachine=tk.StringVar()
        self.HowtouseMedicine=tk.StringVar()
        self.PatientID=tk.StringVar()
        self.NHSNO=tk.StringVar()
        self.PatientName=tk.StringVar()
        self.DOB=tk.StringVar()
        self.PatientAddress=tk.StringVar()
        
        #================================1st label================================
        Label1=tk.Label(self.root,bd=20,relief='ridge',text="Ashwini Hospital,Sangramnagar,Akluj",fg='red',bg='white',font=("times new roman",60,"bold"))
        Label1.pack(side='top',fill="x")
        
        
        #==================================Dataframe====================
        
        dataframe=tk.Frame(self.root,bd=20,relief='ridge')
        dataframe.place(x=0,y=132,width=1520,height=400)
        
        dataframeleft=tk.LabelFrame(dataframe,bd=10,relief='ridge',padx=10,font=("times new roman",12,"bold"),text="Patient Information")
        dataframeleft.place(x=0,y=5,width=980,height=350)
        
        dataframeright=tk.LabelFrame(dataframe,bd=10,relief='ridge',padx=10,font=("times new roman",12,"bold"),text="Prescription")
        dataframeright.place(x=980,y=5,width=460,height=350)
        
        #====================================buttons frame================
        
        dataframebt=tk.Frame(self.root,bd=20,relief='ridge')
        dataframebt.place(x=0,y=530,width=1520,height=90)
        
        #====================================details frame================
        
        dataframedes=tk.Frame(self.root,bd=20,relief='ridge',padx=5)
        dataframedes.place(x=0,y=600,width=1520,height=180)
        
        #=====================================labels of Left frames==================
        
        self.lb1dfl=tk.Label(dataframeleft,padx=2,pady=6,font=("times new roman",12,"bold"),text="Name of Medicine")
        self.lb1dfl.grid(row=0,column=0)
        
        self.combo=ttk.Combobox(dataframeleft,textvariable= 'Nameofmedicine',font=("times new roman",12,"bold"),width=33)
        self.combo['values']=('','Ecosprin','Calaptin','Rabitor','omee','Paracetamol','telvas','amlodipine')
        self.combo.current(0)
        self.combo.grid(row=0,column=1)
        
        self.lb2dfl=tk.Label(dataframeleft,padx=2,pady=6,font=("times new roman",12,"bold"),text="Reference No.")
        self.lb2dfl.grid(row=1,column=0)
        
        self.EN2=tk.Entry(dataframeleft,textvariable='self.ReferenceNo',width=35,font=("times new roman",12,"bold"))
        self.EN2.grid(row=1,column=1)
        
        self.lb3dfl=tk.Label(dataframeleft,padx=2,pady=4,font=("times new roman",12,"bold"),text="Dose")
        self.lb3dfl.grid(row=2,column=0)
        
        self.EN3=tk.Entry(dataframeleft,textvariable='self.Dose',width=35,font=("times new roman",12,"bold"))
        self.EN3.grid(row=2,column=1)
        
        self.lb4dfl=tk.Label(dataframeleft,padx=2,pady=4,font=("times new roman",12,"bold"),text="Medicine Quantity")
        self.lb4dfl.grid(row=3,column=0)
        
        self.EN4=tk.Entry(dataframeleft,textvariable='self.MedicineQuntity',width=35,font=("times new roman",12,"bold"))
        self.EN4.grid(row=3,column=1)
        
        self.lb3dfl=tk.Label(dataframeleft,padx=2,pady=4,font=("times new roman",12,"bold"),text="Lot")
        self.lb3dfl.grid(row=4,column=0)
        
        self.EN5=tk.Entry(dataframeleft,textvariable='self.Lot',width=35,font=("times new roman",12,"bold"))
        self.EN5.grid(row=4,column=1)
        
        self.lb3dfl=tk.Label(dataframeleft,padx=2,pady=4,font=("times new roman",12,"bold"),text="Issue Date")
        self.lb3dfl.grid(row=5,column=0)
        
        self.EN6=tk.Entry(dataframeleft,textvariable='self.Issuedate',width=35,font=("times new roman",12,"bold"))
        self.EN6.grid(row=5,column=1)
        self.lb3dfl=tk.Label(dataframeleft,padx=2,pady=4,font=("times new roman",12,"bold"),text="Expiry Date")
        self.lb3dfl.grid(row=6,column=0)
        
        self.EN7=tk.Entry(dataframeleft,textvariable='self.Expirydate',width=35,font=("times new roman",12,"bold"))
        self.EN7.grid(row=6,column=1)
        
        self.lb3dfl=tk.Label(dataframeleft,padx=2,pady=4,font=("times new roman",12,"bold"),text="Daily Dose")
        self.lb3dfl.grid(row=7,column=0)
        
        self.EN8=tk.Entry(dataframeleft,textvariable='self.Dailydose',width=35,font=("times new roman",12,"bold"))
        self.EN8.grid(row=7,column=1)
        
        self.lb3dfl=tk.Label(dataframeleft,padx=2,pady=4,font=("times new roman",12,"bold"),text="Side Effect")
        self.lb3dfl.grid(row=8,column=0)
        
        self.EN9=tk.Entry(dataframeleft,textvariable='self.sideEffect',width=35,font=("times new roman",12,"bold"))
        self.EN9.grid(row=8,column=1)
        
        
        self.lb1dfl=tk.Label(dataframeleft,padx=2,pady=6,font=("times new roman",12,"bold"),text="More Information")
        self.lb1dfl.grid(row=0,column=2)
        
        self.EN10=tk.Entry(dataframeleft,textvariable='self.FurtherInformation',width=35,font=("times new roman",12,"bold"))
        self.EN10.grid(row=0,column=3)
       
        self.lb2dfl=tk.Label(dataframeleft,padx=2,pady=6,font=("times new roman",12,"bold"),text="Blood Pressure")
        self.lb2dfl.grid(row=1,column=2)
        
        self.EN11=tk.Entry(dataframeleft,textvariable='self.Drivingusingmachine',width=35,font=("times new roman",12,"bold"))
        self.EN11.grid(row=1,column=3)
        
        self.lb3dfl=tk.Label(dataframeleft,padx=2,pady=4,font=("times new roman",12,"bold"),text="Storage Advice")
        self.lb3dfl.grid(row=2,column=2)
        
        self.EN12=tk.Entry(dataframeleft,textvariable='self.Storageadvice',width=35,font=("times new roman",12,"bold"))
        self.EN12.grid(row=2,column=3)
        
        self.lb4dfl=tk.Label(dataframeleft,padx=2,pady=4,font=("times new roman",12,"bold"),text="Medication")
        self.lb4dfl.grid(row=3,column=2)
        
        self.EN13=tk.Entry(dataframeleft,textvariable='self.HowtouseMedicine',width=35,font=("times new roman",12,"bold"))
        self.EN13.grid(row=3,column=3)
        
        self.lb3dfl=tk.Label(dataframeleft,padx=2,pady=4,font=("times new roman",12,"bold"),text="Patient ID")
        self.lb3dfl.grid(row=4,column=2)
        
        self.EN14=tk.Entry(dataframeleft,textvariable='self.PatientID',width=35,font=("times new roman",12,"bold"))
        self.EN14.grid(row=4,column=3)
        
        self.lb3dfl=tk.Label(dataframeleft,padx=2,pady=4,font=("times new roman",12,"bold"),text="NHS No.")
        self.lb3dfl.grid(row=5,column=2)
        
        self.EN15=tk.Entry(dataframeleft,textvariable='self.NHSNO',width=35,font=("times new roman",12,"bold"))
        self.EN15.grid(row=5,column=3)
        
        self.lb3dfl=tk.Label(dataframeleft,padx=2,pady=4,font=("times new roman",12,"bold"),text="Patient Name")
        self.lb3dfl.grid(row=6,column=2)
        
        self.EN16=tk.Entry(dataframeleft,textvariable='self.PatientName',width=35,font=("times new roman",12,"bold"))
        self.EN16.grid(row=6,column=3)
        
        self.lb3dfl=tk.Label(dataframeleft,padx=2,pady=4,font=("times new roman",12,"bold"),text="Date of Birth")
        self.lb3dfl.grid(row=7,column=2)
        
        self.EN17=tk.Entry(dataframeleft,textvariable='self.DOB',width=35,font=("times new roman",12,"bold"))
        self.EN17.grid(row=7,column=3)
        
        self.lb3dfl=tk.Label(dataframeleft,padx=2,pady=4,font=("times new roman",12,"bold"),text="Patient Address")
        self.lb3dfl.grid(row=8,column=2)
        
        self.EN18=tk.Entry(dataframeleft,textvariable='self.PatientAddress',width=35,font=("times new roman",12,"bold"))
        self.EN18.grid(row=8,column=3)
        
        #=====================================labels of right frames==================
        
        self.txtprescription = tk.Text(dataframeright,padx=2,pady=6,width=50,height=16,font=("times new roman",12,"bold"))
        self.txtprescription.grid(row=0,column=0)
        
        #=========================================buttons for operation==================
        
        button1=tk.Button(dataframebt,text="Prescription",fg="white",bg="green",padx=40,pady=10,width=17,font=("times new roman",12,"bold")).grid(row=0,column=0)
        button2=tk.Button(dataframebt,text="Prescription-Data",fg="white",bg="green",padx=40,pady=10,width=17,font=("times new roman",12,"bold"),command=self.iprescriptiondata).grid(row=0,column=1)
        button3=tk.Button(dataframebt,text="Update",fg="white",bg="green",padx=40,pady=10,width=17,font=("times new roman",12,"bold")).grid(row=0,column=2)
        button4=tk.Button(dataframebt,text="Delete",fg="white",bg="green",padx=40,pady=10,width=17,font=("times new roman",12,"bold")).grid(row=0,column=3)
        button5=tk.Button(dataframebt,text="Clear",fg="white",bg="green",padx=40,pady=10,width=17,font=("times new roman",12,"bold")).grid(row=0,column=4)
        button6=tk.Button(dataframebt,text="Exit",fg="white",bg="green",padx=40,pady=10,width=17,font=("times new roman",12,"bold")).grid(row=0,column=5)
        
        #=========================================Scroll bar for description section==================
        
        scrolled_x=ttk.Scrollbar(dataframedes,orient = 'horizontal')
        scrolled_y=ttk.Scrollbar(dataframedes,orient = 'vertical')
        self.Hospital_table=ttk.Treeview(dataframedes,column=('NameofMedicine','ReferenceNo.','Dose','MedicineQuantity',
                                                                'IssueDate','ExpiryDate','DailyDose','SideEffect',
                                                              'BloodPressure','PatientID','NHSNo.','PatientName','DateofBirth','PatientAddress'))
        
        scrolled_x.pack(side='bottom',fill='x')
        scrolled_y.pack(side='right',fill='y')
        
        scrolled_x=ttk.Scrollbar(command= self.Hospital_table.xview)
        scrolled_y=ttk.Scrollbar(command= self.Hospital_table.yview)
  

        self.Hospital_table.heading('NameofMedicine',text='Name of Medicine')
        self.Hospital_table.heading('ReferenceNo.',text='Reference No.')
        self.Hospital_table.heading('Dose',text='Dose')
        self.Hospital_table.heading('MedicineQuantity',text='Medicine Quantity')
        self.Hospital_table.heading('IssueDate',text='Issue Date')
        self.Hospital_table.heading('ExpiryDate',text='Expiry Date')
        self.Hospital_table.heading('DailyDose',text='Daily Dose')
        self.Hospital_table.heading('SideEffect',text='Side Effect')
        self.Hospital_table.heading('BloodPressure',text='Blood Pressure')
        self.Hospital_table.heading('PatientID',text=' Patient ID')
        self.Hospital_table.heading('NHSNo.',text='NHS No.')
        self.Hospital_table.heading('PatientName',text=' Patient Name')
        self.Hospital_table.heading('DateofBirth',text='Date of Birth')
        self.Hospital_table.heading('PatientAddress',text='Patient Address')
        
        self.Hospital_table['show']='headings'
        #resizeing width 
        self.Hospital_table.column('NameofMedicine',width=100)
        self.Hospital_table.column('ReferenceNo.',width=90)
        self.Hospital_table.column('Dose',width=70)
        self.Hospital_table.column('MedicineQuantity',width=100)
        self.Hospital_table.column('IssueDate',width=100)
        self.Hospital_table.column('ExpiryDate',width=100)
        self.Hospital_table.column('DailyDose',width=100)
        self.Hospital_table.column('SideEffect',width=100)
        self.Hospital_table.column('BloodPressure',width=100)
        self.Hospital_table.column('PatientID',width=100)
        self.Hospital_table.column('NHSNo.',width=70)
        self.Hospital_table.column('PatientName',width=110)
        self.Hospital_table.column('DateofBirth',width=100)
        self.Hospital_table.column('PatientAddress',width=100)
        
        self.Hospital_table.pack(fill='both',expand=1)
        self.Hospital_table.bind("<ButtonRelease-1>",self.get_cursor)
        
        self.fetch_data()
        
        #================================Database functionality declaration=============================
        
    def iprescriptiondata(self):
        
        if(self.combo.get()=="" or self.EN2.get()==""):
            messagebox.showerror("Error","Plz Enter Valid Data")
        else:
            conn=mysql.connector.connect(host="localhost",username="root",password="848483",database="mydata")
            mycursor=conn.cursor()
            mycursor.execute("insert into hospital values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)",(self.combo.get(),
                                                                                    self.EN2.get(),
                                                                                    self.EN3.get(),
                                                                                    self.EN4.get(),
                                                                                    self.EN6.get(),
                                                                                    self.EN7.get(),
                                                                                    self.EN8.get(),
                                                                                    self.EN9.get(),
                                                                                    self.EN11.get(),
                                                                                    self.EN14.get(),
                                                                                    self.EN15.get(),
                                                                                    self.EN16.get(),
                                                                                    self.EN17.get(),
                                                                                    self.EN18.get()
                                                                                                       ))
            
            conn.commit()
            self.fetch_data()
            conn.close()
            messagebox.showinfo("Success","Record has been successfully inserted...!")
            
    def fetch_data(self):
            conn=mysql.connector.connect(host="localhost",username="root",password="848483",database="mydata")
            mycursor=conn.cursor()
            mycursor.execute("select*from hospital")
            rows=mycursor.fetchall()
            if len(rows)!=0:
                self.Hospital_table.delete(*self.Hospital_table.get_children())
                for i in rows:
                    self.Hospital_table.insert("",tk.END,values=i)
                conn.commit()
            conn.close()
            
    def get_cursor(event=""):
            self.cursor_row = self.Hospital_table.focus()
            self.content=self.Hospital_table.item(self.cursor_row)
            row=self.content['values']
            a=row[1]
            print(a)
            combo.set(row[0])
            EN2.set(a)
            self.Dose.set(row[2])
            self.MedicineQuntity.set(row[3])
            self.Issuedate.set(row[4])
            self.Expirydate.set(row[5])
            self.Dailydose.set(row[6])
            self.sideEffect.set(row[7])
            self.Drivingusingmachine.set(row[8])
            self.PatientID.set(row[9])
            self.NHSNO.set(row[10])
            self.PatientName.set(row[11])
            self.DOB.set(row[12])
            self.PatientAddress.set(row[13])
            


root=tk.Tk()
ob=Hospital(root)
root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
# TypeError: get_cursor() takes from 0 to 1 positional arguments but 2 were given
